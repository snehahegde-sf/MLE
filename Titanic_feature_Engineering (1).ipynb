# %% [markdown]
# ## Use case: Survival data for passengers of the Titanic

# %% [markdown]
# ### Importing important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from ydata_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder,OrdinalEncoder
import warnings
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
import pickle
from sklearn.pipeline import Pipeline
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
import sklearn
print(sklearn.__version__) # We will be using this version for creating the pipline.
# Out:
# 1.7.2

# %%
# !pip install --upgrade ipython
# Out:
# Requirement already satisfied: ipython in .\miniconda3\envs\py310\lib\site-packages (8.39.0)
# Requirement already satisfied: colorama in .\miniconda3\envs\py310\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in .\miniconda3\envs\py310\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: exceptiongroup in .\miniconda3\envs\py310\lib\site-packages (from ipython) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in .\miniconda3\envs\py310\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in .\miniconda3\envs\py310\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\miniconda3\envs\py310\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in .\miniconda3\envs\py310\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in .\miniconda3\envs\py310\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in .\miniconda3\envs\py310\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in .\miniconda3\envs\py310\lib\site-packages (from ipython) (4.15.0)
# Requirement already satisfied: wcwidth in .\miniconda3\envs\py310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\miniconda3\envs\py310\lib\site-packages (from jedi>=0.16->ipython) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in .\miniconda3\envs\py310\lib\site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\miniconda3\envs\py310\lib\site-packages (from stack_data->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in .\miniconda3\envs\py310\lib\site-packages (from stack_data->ipython) (0.2.3)

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in .\miniconda3\envs\py310\lib\site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in .\miniconda3\envs\py310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (2.2.5)
# Requirement already satisfied: minify-html>=0.15.0 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in .\miniconda3\envs\py310\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in .\miniconda3\envs\py310\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in .\miniconda3\envs\py310\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\miniconda3\envs\py310\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in .\miniconda3\envs\py310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in .\miniconda3\envs\py310\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in .\miniconda3\envs\py310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\miniconda3\envs\py310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in .\miniconda3\envs\py310\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in .\miniconda3\envs\py310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\miniconda3\envs\py310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\miniconda3\envs\py310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\miniconda3\envs\py310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\miniconda3\envs\py310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\miniconda3\envs\py310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\miniconda3\envs\py310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\miniconda3\envs\py310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in .\miniconda3\envs\py310\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in .\miniconda3\envs\py310\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in .\miniconda3\envs\py310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in .\miniconda3\envs\py310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in .\miniconda3\envs\py310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in .\miniconda3\envs\py310\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
data = pd.read_csv("train.csv")  # loading dataset

# %% [markdown]
# # Basic Checks '

# %%
data.head()   # showing first 5 rows and columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()   # showing last 5 rows and columns
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.shape  # it showing
# Out:
# (891, 12)

# %%
# This all columns are not important that's why we are going to drop mentioned columns
data=data.drop(['Ticket','PassengerId','Name','Cabin'], axis=1)

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# # Checking for outliers '

# %%
# Select numerical columns
numerical_cols = data.select_dtypes(include=['int', 'float']).columns

# Create box plots for all numerical features
plt.figure(figsize=(12, 8))
data[numerical_cols].boxplot()
plt.xticks(rotation=45)
plt.title('Box plots for Numerical Features')
plt.ylabel('Value')
plt.xlabel('Feature')
plt.show()

# %% [markdown]
# ## What is an outliers ?

# %% [markdown]
# - An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.
# - In a sense, this definition leaves it up to the analyst (or a consensus process) to decide what will be considered abnormal.
# - An outlier is a single data point that goes far outside the average value of a group of statistics.
# - Outliers may be exceptions that stand outside individual samples of populations as well.
# - In a more general context, an outlier is an individual that is markedly different from the norm in some respect.

# %%
data.info()   # it showing information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
data.describe()   # it showing statistics informations
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # EDA '

# %% [markdown]
# # Correlation Matrix '

# %%
sns.heatmap(data.select_dtypes(include=['int', 'float']).corr())
# Out:
# <Axes: >

# %%
np.where(data.select_dtypes(include=['int', 'float']).corr()>0.9)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([0, 1, 2, 3, 4, 5]))

# %% [markdown]
# - A correlation matrix is a statistical technique used to evaluate the relationship between two variables in a data set.
# - The matrix is a table in which every cell contains a correlation coefficient, where 1 is considered a strong relationship between variables, 0 a neutral relationship and -1 a not strong relationship.
# - We can also set up our own threshold values based on the datasets.

# %% [markdown]
# # Data  PreProcessing '

# %% [markdown]
# - Data preprocessing is a process of preparing the raw data and making it suitable for a machine learning model.
# - It is the first and crucial step while creating a machine learning model.
# - When creating a machine learning project, it is not always a case that we come across the clean and formatted data.

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# ### These are continuous columns so we will use standard scaler. But we can also divide age by 100 and that can be the transformation for age. Trasformation on age is just to see how we can apply custom transformations without using pre built scikit-learn functions.

# %% [markdown]
# - Fare

# %%
data[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# # Survived :

# %%
data.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# - We won't be do anything for this column.

# %% [markdown]
# # Using One Hot Encoder here '

# %% [markdown]
# ## Sex :

# %%
data.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# - We will be using OHE for this column.

# %% [markdown]
# - One-hot encoding is the most widely used categorical encoding technique. It is suitable for nominal categorical variables, where the categories have no inherent order or relationship. The idea behind one-hot encoding is to represent each category as a binary vector. Here’s how it works:
#
# - For each category in a categorical column, a new binary column is created.
#
# - The binary column will have a value of 1 if the class is present, else it will be zero.

# %% [markdown]
# # SibSp

# %%
data.SibSp.value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %% [markdown]
#  - The values were already arranged ordinally so we don't have to do anything.

# %% [markdown]
# # Parch :

# %%
data.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
#  - The values were already arranged ordinally so we don't have to do anything.

# %% [markdown]
# # Using Label Encoder here '

# %% [markdown]
# ## Embarked :

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# - We will be using label encoder for this column.

# %% [markdown]
# - Label encoding is suitable for categorical features with only two distinct categories.
#
# - In this technique, each category is assigned a unique integer label. Categories are assigned integer values starting from 0.
#
# - For example, if you have an ordinal categorical feature “Size” with values “Small,” “Medium,” and “Large,” label encoding would convert it.

# %% [markdown]
# # Function transformer :

# %%
def divide_by_100(x):
    return (x/100)

# %% [markdown]
# - we can use FunctionTrasformer to use our own custom function for transformation.
# - So we will use this custom function whe we are defining the pipeline.
# - We can define our funtion transformer whenever we need that in our pipeline.

# %%
custom=FunctionTransformer(divide_by_100)

# %% [markdown]
# # Using Modified Label Encoder '

# %% [markdown]
# ## Column Transformer :

# %%
class ModifiedLabelEncoder(LabelEncoder):
    def fit_transform(self, y, *args, **kwargs):
        return super().fit_transform(y).reshape(-1, 1)

    def transform(self, y, *args, **kwargs):
        return super().transform(y).reshape(-1, 1)

# %% [markdown]
# - You use the ColumnTransformer to transform each column set separately and then you can use the pipeline for multiple transformations of the same columns.
# - Column Transformer is a scikit-learn class used to create and apply separate transformers for numerical and categorical data. - To create transformers we need to specify the transformer object and pass the list of transformations inside a tuple along with the column on which you want to apply the transformation.

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
# We are defining here each columns that which scaling techniques are used for which columns :


OHE_columns=['Sex']
standard_scaler=['Fare']
function_trasformer=['Age']
label_encoder=['Embarked']

# %% [markdown]
# # Steps of preprocesing for features:
# - **LabelEncoder for**    :  'Embarked'
# - **One hot encoder for** :  'Sex'
# - **Standard scaler for** :  'Fare'
# - **Function transformer**:  'Age'

# %%
passthrough=["Pclass", "SibSp", "Parch", "Survived"]

# %%
def same(x):
    return x

# %%
no_trans=FunctionTransformer(same)

# %% [markdown]
# # Defining the preprocessor :

# %%
preprocessor=ColumnTransformer([('OHE_columns',OneHotEncoder(),OHE_columns),
                                ('standard_scaler',StandardScaler(),standard_scaler),
                                ('custom',custom,function_trasformer),
                                ('Label_encoder',ModifiedLabelEncoder(),['Embarked']),
                                ('Pass_through',no_trans,passthrough)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OHE_columns', OneHotEncoder(), ['Sex']),
#                                 ('standard_scaler', StandardScaler(), ['Fare']),
#                                 ('custom',
#                                  FunctionTransformer(func=<function divide_by_100 at 0x0000018F8A1DA4D0>),
#                                  ['Age']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['Embarked']),
#                                 ('Pass_through',
#                                  FunctionTransformer(func=<function same at 0x0000018F8A1DA680>),
#                                  ['Pclass', 'SibSp', 'Parch', 'Survived'])])

# %% [markdown]
# # Creating Pickle file '

# %%
file = open("Titanic.pkl","wb")

# %%
pickle.dump(preprocessor,file)

# %%
file.close()

# %%
file = open("Titanic.pkl","rb")

# %%
pre = pickle.load(file)

# %%
pre
# Out:
# ColumnTransformer(transformers=[('OHE_columns', OneHotEncoder(), ['Sex']),
#                                 ('standard_scaler', StandardScaler(), ['Fare']),
#                                 ('custom',
#                                  FunctionTransformer(func=<function divide_by_100 at 0x0000018F8A1DA4D0>),
#                                  ['Age']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['Embarked']),
#                                 ('Pass_through',
#                                  FunctionTransformer(func=<function same at 0x0000018F8A1DA680>),
#                                  ['Pclass', 'SibSp', 'Parch', 'Survived'])])
